# %% [markdown]
# # Pandas Interpolate (Part -7)

# %% [markdown]
# # ~ Pandas interpolae() function is basically used to fill NaN values in dataframe or series.
# # Syntax: DataFrame.interpolate()
# # Series.interpolate()
# # Parameters: methos ----------------    inplace
# #             axis --------------------        limit_direction
# #             limit  -----------------------    limit_area

# %%
import pandas as pd

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.interpolate()      #  ( method = 'Linear' )
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.interpolate(method = 'time')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
type(df.Date[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-894535e30701> in <module>
# ----> 1 type(df.Date[0])
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv'  )
df
