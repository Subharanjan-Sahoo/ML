# %% [markdown]
# # How to Write CSV File in Pandas  (Part - 4)

# %%
import pandas as pd

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv',nrows=5)
df
# Out:
#    Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2020                     Level 1                 99999
# 1  2020                     Level 1                 99999
# 2  2020                     Level 1                 99999
# 3  2020                     Level 1                 99999
# 4  2020                     Level 1                 99999
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv', usecols=[0,1])
df
# Out:
#        Year Industry_aggregation_NZSIOC
# 0      2020                     Level 1
# 1      2020                     Level 1
# 2      2020                     Level 1
# 3      2020                     Level 1
# 4      2020                     Level 1
# ...     ...                         ...
# 37075  2013                     Level 3
# 37076  2013                     Level 3
# 37077  2013                     Level 3
# 37078  2013                     Level 3
# 37079  2013                     Level 3
#
# [37080 rows x 2 columns]

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv',usecols=[1,3,5])
df
# Out:
#       Industry_aggregation_NZSIOC        Industry_name_NZSIOC Variable_code
# 0                         Level 1              All industries           H01
# 1                         Level 1              All industries           H04
# 2                         Level 1              All industries           H05
# 3                         Level 1              All industries           H07
# 4                         Level 1              All industries           H08
# ...                           ...                         ...           ...
# 37075                     Level 3  Food product manufacturing           H37
# 37076                     Level 3  Food product manufacturing           H38
# 37077                     Level 3  Food product manufacturing           H39
# 37078                     Level 3  Food product manufacturing           H40
# 37079                     Level 3  Food product manufacturing           H41
#
# [37080 rows x 3 columns]

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv',skiprows=1)
df
# Out:
#        2020  Level 1  99999              All industries  Dollars (millions)  \
# 0      2020  Level 1  99999              All industries  Dollars (millions)
# 1      2020  Level 1  99999              All industries  Dollars (millions)
# 2      2020  Level 1  99999              All industries  Dollars (millions)
# 3      2020  Level 1  99999              All industries  Dollars (millions)
# 4      2020  Level 1  99999              All industries  Dollars (millions)
# ...     ...      ...    ...                         ...                 ...
# 37074  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37075  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37076  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37077  2013  Level 3   ZZ11  Food product manufacturing          Percentage
# 37078  2013  Level 3   ZZ11  Food product manufacturing          Percentage
#
# ...

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv', skiprows=[5])   #index []
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv', index_col='Year')   
df
# Out:
#      Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 2020                     Level 1                99999
# 2020                     Level 1                99999
# 2020                     Level 1                99999
# 2020                     Level 1                99999
# 2020                     Level 1                99999
# ...                          ...                  ...
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 2020              All industries  Dollars (millions)           H01
# 2020              All industries  Dollars (millions)           H04
# 2020              All industries  Dollars (millions)           H05
# ...
