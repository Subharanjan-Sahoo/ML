# %% [markdown]
# # Handling Missing Values (part - 5)

# %%
import pandas as pd

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1         Not avalable
# 4      2020                     Level 1            No values
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
#  NAN (NOT A NUMBER) NULL Value

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv', na_values =['Not avalable','No values'])
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv', na_values ={'Industry_code_NZSIOC':'Not avalable'}) #collum wise
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1            No values
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1         Not avalable
# 4      2020                     Level 1            No values
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv', keep_default_na = False)
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                 NULL
# 3      2020                     Level 1         Not avalable
# 4      2020                     Level 1            No values
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)
# ...

# %%
# na_filter = False (If no NAN Value are there in the csv File (This boost the Preformance+))

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.isnull()
# Out:
#         Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      False                        False                 False
# 1      False                        False                 False
# 2      False                        False                  True
# 3      False                        False                  True
# 4      False                        False                  True
# ...      ...                          ...                   ...
# 37075  False                        False                 False
# 37076  False                        False                 False
# 37077  False                        False                 False
# 37078  False                        False                 False
# 37079  False                        False                 False
#
#        Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                     False  False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# Year                            0
# Industry_aggregation_NZSIOC     0
# Industry_code_NZSIOC            3
# Industry_name_NZSIOC            0
# Units                          10
# Variable_code                  13
# Variable_name                   0
# Variable_category               0
# Value                           0
# Industry_code_ANZSIC06          0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 26

# %%
df.notnull()
# Out:
#        Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      True                         True                  True
# 1      True                         True                  True
# 2      True                         True                 False
# 3      True                         True                 False
# 4      True                         True                 False
# ...     ...                          ...                   ...
# 37075  True                         True                  True
# 37076  True                         True                  True
# 37077  True                         True                  True
# 37078  True                         True                  True
# 37079  True                         True                  True
#
#        Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                      True   True           True           True
# 1                      True   True          False           True
# ...

# %%
df.notnull().sum()
# Out:
# Year                           37080
# Industry_aggregation_NZSIOC    37080
# Industry_code_NZSIOC           37077
# Industry_name_NZSIOC           37080
# Units                          37070
# Variable_code                  37067
# Variable_name                  37080
# Variable_category              37080
# Value                          37080
# Industry_code_ANZSIC06         37080
# dtype: int64

# %% [markdown]
# # Series

# %%
import numpy as np
sr = pd.Series([1,2,3,np.nan,4,np.NAN])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %% [markdown]
# # dropna()

# %%
df = pd.read_csv('E:\\ML\\annualenterprise.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.dropna()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 6      2020                     Level 1                99999
# 7      2020                     Level 1                99999
# 8      2020                     Level 1                99999
# 9      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 6                  All industries  Dollars (millions)           H10
# ...

# %%
df.dropna(axis = 1)
# Out:
#        Year Industry_aggregation_NZSIOC        Industry_name_NZSIOC  \
# 0      2020                     Level 1              All industries
# 1      2020                     Level 1              All industries
# 2      2020                     Level 1              All industries
# 3      2020                     Level 1              All industries
# 4      2020                     Level 1              All industries
# ...     ...                         ...                         ...
# 37075  2013                     Level 3  Food product manufacturing
# 37076  2013                     Level 3  Food product manufacturing
# 37077  2013                     Level 3  Food product manufacturing
# 37078  2013                     Level 3  Food product manufacturing
# 37079  2013                     Level 3  Food product manufacturing
#
#                                          Variable_name      Variable_category  \
# ...

# %%
df.dropna(how = 'any')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 6      2020                     Level 1                99999
# 7      2020                     Level 1                99999
# 8      2020                     Level 1                99999
# 9      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 6                  All industries  Dollars (millions)           H10
# ...

# %%
df.dropna(axis=1,how = 'any')
# Out:
#        Year Industry_aggregation_NZSIOC        Industry_name_NZSIOC  \
# 0      2020                     Level 1              All industries
# 1      2020                     Level 1              All industries
# 2      2020                     Level 1              All industries
# 3      2020                     Level 1              All industries
# 4      2020                     Level 1              All industries
# ...     ...                         ...                         ...
# 37075  2013                     Level 3  Food product manufacturing
# 37076  2013                     Level 3  Food product manufacturing
# 37077  2013                     Level 3  Food product manufacturing
# 37078  2013                     Level 3  Food product manufacturing
# 37079  2013                     Level 3  Food product manufacturing
#
#                                          Variable_name      Variable_category  \
# ...

# %%
df.dropna(thresh = 10 )
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 6      2020                     Level 1                99999
# 7      2020                     Level 1                99999
# 8      2020                     Level 1                99999
# 9      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 6                  All industries  Dollars (millions)           H10
# ...

# %%
df.dropna(subset = ['Industry_code_NZSIOC'])
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 5      2020                     Level 1                99999
# 6      2020                     Level 1                99999
# 7      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.dropna(inplace = True)
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 6      2020                     Level 1                99999
# 7      2020                     Level 1                99999
# 8      2020                     Level 1                99999
# 9      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 6                  All industries  Dollars (millions)           H10
# ...
