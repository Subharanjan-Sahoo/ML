# %% [markdown]
# # Pandas replace() Values (Part - 6)

# %%
import pandas as pd

# %%
df =pd.read_csv('E:\\ML\\annualenterprise.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.replace(to_replace= '2013' ,value = "2000")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.replace(to_replace= 2013 ,value = 2000)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2000                     Level 3                 ZZ11
# 37076  2000                     Level 3                 ZZ11
# 37077  2000                     Level 3                 ZZ11
# 37078  2000                     Level 3                 ZZ11
# 37079  2000                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.replace(2000,2013)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.replace([2013,2020],2000)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2000                     Level 1                99999
# 1      2000                     Level 1                99999
# 2      2000                     Level 1                  NaN
# 3      2000                     Level 1                  NaN
# 4      2000                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2000                     Level 3                 ZZ11
# 37076  2000                     Level 3                 ZZ11
# 37077  2000                     Level 3                 ZZ11
# 37078  2000                     Level 3                 ZZ11
# 37079  2000                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.replace('[A-Za-z]',0)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.replace('[A-Za-z]',0 , regex = True)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                           0                99999
# 1      2020                           0                99999
# 2      2020                           0                  NaN
# 3      2020                           0                  NaN
# 4      2020                           0                  NaN
# ...     ...                         ...                  ...
# 37075  2013                           0                    0
# 37076  2013                           0                    0
# 37077  2013                           0                    0
# 37078  2013                           0                    0
# 37079  2013                           0                    0
#
#       Industry_name_NZSIOC Units Variable_code Variable_name  \
# 0                        0     0             0             0
# 1                        0     0           NaN             0
# ...

# %%
df.replace({'Industry_name_NZSIOC': '[A-Za-z]'}, 0, regex = True)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#       Industry_name_NZSIOC               Units Variable_code  \
# 0                        0  Dollars (millions)           H01
# 1                        0  Dollars (millions)           NaN
# ...

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df.replace('All industries',method = 'bfill')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#                  Industry_name_NZSIOC               Units Variable_code  \
# 0      Horticulture and Fruit Growing  Dollars (millions)           H01
# 1      Horticulture and Fruit Growing  Dollars (millions)           NaN
# ...

# %%
df.replace(0, method = 'bfill' ,limit =2)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                  NaN
# 3      2020                     Level 1                  NaN
# 4      2020                     Level 1                  NaN
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           NaN
# ...
